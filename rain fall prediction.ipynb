# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('weatherAUS.csv')
pd.pandas.set_option('display.max_columns',None)
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0           W           44.0          W        WNW          20.0
# 1         WNW           44.0        NNW        WSW           4.0
# 2         WSW           46.0          W        WSW          19.0
# 3          NE           24.0         SE          E          11.0
# 4           W           41.0        ENE         NW           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# ...

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                   count         mean        std    min     25%     50%  \
# MinTemp        143975.0    12.194034   6.398495   -8.5     7.6    12.0
# MaxTemp        144199.0    23.221348   7.119049   -4.8    17.9    22.6
# Rainfall       142199.0     2.360918   8.478060    0.0     0.0     0.0
# Evaporation     82670.0     5.468232   4.193704    0.0     2.6     4.8
# Sunshine        75625.0     7.611178   3.785483    0.0     4.8     8.4
# WindGustSpeed  135197.0    40.035230  13.607062    6.0    31.0    39.0
# WindSpeed9am   143693.0    14.043426   8.915375    0.0     7.0    13.0
# WindSpeed3pm   142398.0    18.662657   8.809800    0.0    13.0    19.0
# Humidity9am    142806.0    68.880831  19.029164    0.0    57.0    70.0
# Humidity3pm    140953.0    51.539116  20.795902    0.0    37.0    52.0
# Pressure9am    130395.0  1017.649940   7.106530  980.5  1012.9  1017.6
# Pressure3pm    130432.0  1015.255889   7.037414  977.1  1010.4  1015.2
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.736555  0.103938     0.466993  0.072586
# MaxTemp        0.736555  1.000000 -0.074992     0.587932  0.470156
# Rainfall       0.103938 -0.074992  1.000000    -0.064351 -0.227549
# Evaporation    0.466993  0.587932 -0.064351     1.000000  0.365602
# Sunshine       0.072586  0.470156 -0.227549     0.365602  1.000000
# WindGustSpeed  0.177415  0.067615  0.133659     0.203021 -0.034750
# WindSpeed9am   0.175064  0.014450  0.087338     0.193084  0.005499
# WindSpeed3pm   0.175173  0.050300  0.057887     0.129400  0.053834
# Humidity9am   -0.232899 -0.504110  0.224405    -0.504092 -0.490819
# Humidity3pm    0.006089 -0.508855  0.255755    -0.390243 -0.629130
# Pressure9am   -0.450970 -0.332061 -0.168154    -0.270362  0.041970
# Pressure3pm   -0.461292 -0.427167 -0.126534    -0.293581 -0.019719
# Cloud9am       0.078754 -0.289370  0.198528    -0.183793 -0.675323
# ...

# %%
plt.figure(figsize=(14,7))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, xticklabels=corr_matrix.columns,yticklabels=corr_matrix.columns)
plt.title("Correlation between Features")
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.heatmap(df.isnull(),yticklabels = False , cbar = False ,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
df.drop(['Evaporation','Sunshine','Cloud9am','Cloud3pm'], axis=1, inplace=True)

# %%
plt.figure(figsize=(14,7))
sns.heatmap(df.isnull(),yticklabels = False , cbar = False ,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.MinTemp.fillna(value=df.MinTemp.mean(),inplace = True)   #data normally distributed
df.MaxTemp.fillna(value=df.MaxTemp.mean(),inplace = True)   #data normally distributed

# %%
plt.figure(figsize=(15,5))
plt.title('Rainfall per day')
plt.xlabel('Rainfall in mm')
plt.ylabel('Frequency')
plt.hist(df.Rainfall, bins=100, color='blue');

# %%
df.Rainfall.fillna(value=0,inplace = True)  # not following normal distribution so mode is prefered

# %%
df.WindGustSpeed.fillna(value=df.WindGustSpeed.mean(),inplace = True)
df.Humidity9am.fillna(value=df.Humidity9am.mean(),inplace = True)
df.Humidity3pm.fillna(value=df.Humidity3pm.mean(),inplace = True)
df.Pressure9am.fillna(value=df.Pressure9am.mean(),inplace = True)
df.Pressure3pm.fillna(value=df.Pressure3pm.mean(),inplace = True)
df.Temp9am.fillna(value=df.Temp9am.mean(),inplace = True)
df.Temp3pm.fillna(value=df.Temp3pm.mean(),inplace = True)

# %%
df.dropna(subset=['WindGustDir', 'WindDir9am', 'WindDir3pm'],inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126840 entries, 0 to 145458
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           126840 non-null  object
#  1   Location       126840 non-null  object
#  2   MinTemp        126840 non-null  float64
#  3   MaxTemp        126840 non-null  float64
#  4   Rainfall       126840 non-null  float64
#  5   WindGustDir    126840 non-null  object
#  6   WindGustSpeed  126840 non-null  float64
#  7   WindDir9am     126840 non-null  object
#  8   WindDir3pm     126840 non-null  object
#  9   WindSpeed9am   126840 non-null  float64
#  10  WindSpeed3pm   126840 non-null  float64
#  11  Humidity9am    126840 non-null  float64
#  12  Humidity3pm    126840 non-null  float64
#  13  Pressure9am    126840 non-null  float64
#  14  Pressure3pm    126840 non-null  float64
#  15  Temp9am        126840 non-null  float64
# ...

# %%
df = pd.get_dummies(columns=['RainToday','RainTomorrow'],data = df,drop_first = True)

# %%
plt.figure(figsize=(14,7))
sns.heatmap(df.isnull(),yticklabels = False , cbar = False, cmap= "viridis")
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp             0
# MaxTemp             0
# Rainfall            0
# WindGustDir         0
# WindGustSpeed       0
# WindDir9am          0
# WindDir3pm          0
# WindSpeed9am        0
# WindSpeed3pm        0
# Humidity9am         0
# Humidity3pm         0
# Pressure9am         0
# Pressure3pm         0
# Temp9am             0
# Temp3pm             0
# RainToday_Yes       0
# RainTomorrow_Yes    0
# dtype: int64

# %%
df.Date = pd.to_datetime(df.Date)
df.dtypes
# Out:
# Date                datetime64[ns]
# Location                    object
# MinTemp                    float64
# MaxTemp                    float64
# Rainfall                   float64
# WindGustDir                 object
# WindGustSpeed              float64
# WindDir9am                  object
# WindDir3pm                  object
# WindSpeed9am               float64
# WindSpeed3pm               float64
# Humidity9am                float64
# Humidity3pm                float64
# Pressure9am                float64
# Pressure3pm                float64
# Temp9am                    float64
# Temp3pm                    float64
# RainToday_Yes                uint8
# RainTomorrow_Yes             uint8
# dtype: object

# %%
df['Month'] = df.Date.dt.month

# %%
rainfall_per_month=df.groupby('Month')['Rainfall'].sum()

# %%
plt.figure(figsize=(14, 7))
plt.bar(rainfall_per_month.index,rainfall_per_month.values)
plt.xticks(labels=rainfall_per_month.index, ticks=range(1,13))
plt.xlabel("months")
# label y axis
plt.ylabel("rainfall")
# Out:
# Text(0, 0.5, 'rainfall')

# %%
df.drop(columns=['Date','Location'],axis=1,inplace = True)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='MinTemp',y='MaxTemp',data=df,hue='RainTomorrow_Yes')
# Out:
# <AxesSubplot:xlabel='MinTemp', ylabel='MaxTemp'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='MinTemp',y='MaxTemp',data=df,hue='RainToday_Yes')
# Out:
# <AxesSubplot:xlabel='MinTemp', ylabel='MaxTemp'>

# %%
df = pd.get_dummies(columns=['WindGustDir','WindDir9am','WindDir3pm'],data = df,drop_first = True)

# %%
df.shape
# Out:
# (126840, 60)

# %%
from sklearn.model_selection import train_test_split

# %%
x= df.drop('RainTomorrow_Yes', axis=1)
y= df.RainTomorrow_Yes

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2, random_state=50)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90     19839
#            1       0.71      0.46      0.56      5529
#
#     accuracy                           0.84     25368
#    macro avg       0.79      0.70      0.73     25368
# weighted avg       0.83      0.84      0.83     25368

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[18799  1040]
#  [ 2974  2555]]

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8417691579943235

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(model,x_train,y_train,cv=5,scoring='accuracy')

# %%
score.mean()
# Out:
# 0.839837581928504
